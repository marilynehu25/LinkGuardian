# %%
import pandas as pd
import numpy as np
from urllib.parse import urlparse, urlunparse
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# ## **Fonctions**

# %%
def fix_encoding(text):
    if isinstance(text, str):
        try:
            return text.encode("latin1").decode("utf-8")
        except:
            return text
    return text

# %%
def extract_domain(url):
    parsed = urlparse(url)
    domain = parsed.netloc.lower()

    # Retirer "www."
    if domain.startswith("www."):
        domain = domain[4:]
    
    return domain

# %%
def extract_domain_name(url):
    parsed = urlparse(url)
    domain = (parsed.hostname or "").lower()

    # enlever "www."
    domain = domain.removeprefix("www.")

    parts = domain.split(".")

    if len(parts) >= 2:
        return parts[-2]   # avant le dernier point
    else:
        return domain

# %%
def find_tag(url, list_tag):
    if not isinstance(url, str):
        return ""

    url = url.lower()

    for tag in list_tag:
        if tag in url:
            return tag
    
    return ""

# %%
def clean_url(url):
    """Supprime http, https, www et garde uniquement domaine + chemin."""
    url = url.strip().lower()

    # enlever http:// ou https://
    url = url.replace("https://", "").replace("http://", "")

    # enlever www.
    url = url.removeprefix("www.")

    # enlever trailing slash
    if url.endswith("/"):
        url = url[:-1]

    return url

def get_anchor_text(page_url, target_url):
    try:
        response = requests.get(page_url, timeout=10, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()

    except Exception as e:
        return None, f"Page inaccessible: {e}"

    soup = BeautifulSoup(response.text, "lxml")

    # normalisation du lien à chercher
    target_clean = clean_url(target_url)

    # Parcourir tous les <a>
    for a in soup.find_all("a", href=True):
        href = a["href"].strip().lower()

        # cas 1 : href complet → nettoyage
        href_clean = clean_url(href)

        # cas 2 : href relatif → on compare sans domaine
        # exemple : target = "example.com/page"
        #           href = "/page"
        if href_clean in target_clean or target_clean in href_clean:
            anchor = a.get_text(strip=True)
            return anchor, None

    return None, "Lien introuvable dans la page"

# %% [markdown]
# ## **Données**

# %%
df = pd.read_excel("Soumettre.xlsx")
for col in df.columns:
    df[col] = df[col].map(fix_encoding)

# %%
df
# Out:
#                                                     URL            Tag  \
# 0                                                   NaN  promovacances
# 1     https://www.destinationlemonde.com/destination...  promovacances
# 2                                                   NaN  promovacances
# 3                                                   NaN  promovacances
# 4     https://www.saddy.fr/voyages/avantages-des-cir...  promovacances
# ...                                                 ...            ...
# 3119  https://www.chateau-conros.com/sur-quelle-ile-...  promovacances
# 3120  https://www.terresdenvies.com/quelles-activite...  promovacances
# 3121  https://www.quartdetours.fr/opter-pour-un-voya...  promovacances
# 3122  https://www.evalys-bus.fr/quels-sont-les-avant...  promovacances
# 3123  https://www.henrietagnes.com/sejour-en-grece-s...  promovacances
#
#      Plateforme                                      link_to_check  \
# 0     Soumettre  https://www.promovacances.com/vacances-sejour-...
# 1     Soumettre  https://www.promovacances.com/vacances-sejour-...
# 2     Soumettre  https://www.promovacances.com/vacances-sejour-...
# 3     Soumettre  https://www.promovacances.com/vacances-sejour-...
# 4     Soumettre  https://www.promovacances.com/vacances/circuit...
# ...         ...                                                ...
# 3119  Soumettre  https://www.promovacances.com/vacances-sejour-...
# 3120  Soumettre  https://www.promovacances.com/vacances-sejour-...
# 3121  Soumettre  https://www.promovacances.com/vacances-sejour-...
# 3122  Soumettre  https://www.promovacances.com/vacances-sejour-...
# 3123  Soumettre  https://www.promovacances.com/vacances-sejour-...
#
#                                         anchor_text
# 0                                               NaN
# 1     séjour en République Dominicaine tout compris
# 2                                               NaN
# 3                                               NaN
# 4         Découvrir le Kenya en circuit touristique
# ...                                             ...
# 3119                       faire un voyage en Grèce
# 3120                  Pendant votre Voyage en Grèce
# 3121              au cours de votre voyage en Grèce
# 3122                     optez pour un voyage Grèce
# 3123                     lors de votre voyage Grèce
#
# [3124 rows x 5 columns]

# %% [markdown]
# ## **1) Traitement des tags**

# %%
mask = df['link_to_check'].notna()
df.loc[mask, 'Tag'] = df.loc[mask, 'link_to_check'].astype(str).apply(extract_domain_name)

# %% [markdown]
# ## **2) Traitement des ancres et des backlinks**

# %%
mask_search_anchor = df['URL'].notna() & df['anchor_text'].isna()

df[mask_search_anchor]
# Out:
#                                                     URL             Tag  \
# 46    https://www.paris-normandie.fr/id657777/articl...   promovacances
# 68    https://www.courrier-picard.fr/id654609/articl...   promovacances
# 69    https://www.lemessager.fr/649340692/article/20...   promovacances
# 191           https://www.webwiki.fr/promocroisiere.com
# 207   https://www.lavoixdunord.fr/1625592/article/20...  promocroisiere
# 223              https://www.webwiki.fr/abcroisiere.com
# 239   https://www.lavoixdunord.fr/1614215/article/20...     abcroisiere
# 270   https://voyages-intrepides.com/croatie-comment...   promovacances
# 350   https://wholeterrain.org/divertissement/croisi...  promocroisiere
# 363   https://www.fox-voyage.fr/croisiere-autour-du-...  promocroisiere
# 391    https://luxe.net/cap-vert-levasion-sauvage-en...   promovacances
# 394   https://www.provenceweb.fr/f/actu/magazine/pro...            fram
# 651   https://www.voyagesphotosmanu.com/travel/les-d...            fram
# 1080  https://ghostsquadron.com/?s=Les+avantages+du+...   promovacances
# 1394  https://www.cafecitronparis.com/5-excellentes-...   promovacances
# 1555                     https://www.fureurdunoir.info/  promocroisiere
# 1927  https://www.hotelssabah.com/quel-est-linteret-...   promovacances
# 1941  https://www.guide-vols-low-cost.fr/que-faire-a...   promovacances
# 1966  https://www.voyages-voyage.com/pourquoi-choisi...   promovacances
# 1987  https://voyageblog.fr/quels-sont-les-avantages...   promovacances
# 2140  https://lepetitjournal.com/dublin/meilleurs-en...             NaN
# 2149  https://mesdoudouxetcompagnie.fr/2022/10/4-voy...             NaN
# 2150  https://www.guideastuces.com/A14438-5-bonnes-r...             NaN
# 2151  https://modesdevie.com/top-4-des-compagnies-de...             NaN
# 2185  https://www.voyages-voyage.com/pourquoi-opter-...            fram
# 2196  https://www.le-off.be/quels-sont-les-lieux-inc...     abcroisiere
# 2244  https://www.airvacances.fr/astuces-voyager-fai...   partirpascher
# 2310  https://www.airvacances.fr/partir-en-vacances-...     abcroisiere
# 2318  https://www.i-travelled.com/voyage-en-croisier...     abcroisiere
# 2353  https://www.fureurdunoir.info/partir-en-voyage...   promovacances
# 2758  https://www.convergence08.org/voyages/top-5-de...            fram
# 2792  https://www.evalys-bus.fr/camping-cote-dazur-q...            fram
# 2793  https://www.planete-crocodiles.net/cote-dazur-...            fram
# 2798  https://www.savennieres.com/les-activites-vaca...            fram
# 2808  https://www.mamachanblog.net/lifestyle/faire-d...   promovacances
# 2830  https://www.quartdetours.fr/criteres-de-choix-...             NaN
# 2862  https://www.chanoines-lagrasse.com/les-croisie...             NaN
# 2863  https://www.campingdelacroixdarles.com/quelles...             NaN
# 2873  https://www.chambreshotesjolivet.fr/croisiere-...             NaN
# 2874  https://www.refuge-jeandel.com/cabine-de-crois...             NaN
# 2882  https://www.lalignedhorizon.org/criteres-de-ch...             NaN
# 2883  https://www.tourisme-jouarre.com/comment-payer...             NaN
# 2892  https://www.voyages-thematiques.com/voyage-a-b...            fram
# 2902  https://www.sensationskite.com/un-navire-de-cr...             NaN
# 2933  https://www.camping-car-occasion.net/blog/cabi...             NaN
# 2961  https://www.mamanpascommelesautresoupresque.fr...   promovacances
# 3015  https://maxillo-lehavre.fr/pourquoi-opter-pour...   promovacances
#
#      Plateforme                                      link_to_check anchor_text
# 46    Soumettre                     https://www.promovacances.com/         NaN
# 68    Soumettre  https://www.promovacances.com/vacances-sejour-...         NaN
# 69    Soumettre  https://www.promovacances.com/vacances-sejour-...         NaN
# 191   Soumettre                                            http://         NaN
# 207   Soumettre  https://www.promocroisiere.com/fr/croisieres/c...         NaN
# 223   Soumettre                                            http://         NaN
# 239   Soumettre  https://www.abcroisiere.com/fr/croisieres/croi...         NaN
# 270   Soumettre  https://www.promovacances.com/vacances-sejour-...         NaN
# 350   Soumettre  https://www.promocroisiere.com/fr/bateau-norwe...         NaN
# 363   Soumettre  https://www.promocroisiere.com/fr/croisieres/c...         NaN
# 391   Soumettre  https://www.promovacances.com/vacances-sejour-...         NaN
# 394   Soumettre                               https://www.fram.fr/         NaN
# 651   Soumettre                               https://www.fram.fr/         NaN
# 1080  Soumettre                     https://www.promovacances.com/         NaN
# 1394  Soumettre  https://www.promovacances.com/france/camping-c...         NaN
# 1555  Soumettre                    https://www.promocroisiere.com/         NaN
# 1927  Soumettre  https://www.promovacances.com/vacances-sejour-...         NaN
# 1941  Soumettre  https://www.promovacances.com/vacances-sejour-...         NaN
# 1966  Soumettre  https://www.promovacances.com/france/camping-o...         NaN
# 1987  Soumettre  https://www.promovacances.com/france/camping-c...         NaN
# 2140  Soumettre                                                NaN         NaN
# 2149  Soumettre                                                NaN         NaN
# 2150  Soumettre                                                NaN         NaN
# 2151  Soumettre                                                NaN         NaN
# 2185  Soumettre  https://www.fram.fr/espagne/sejour-vacances-vo...         NaN
# 2196  Soumettre                       https://www.abcroisiere.com/         NaN
# 2244  Soumettre                     https://www.partirpascher.com/         NaN
# 2310  Soumettre                       https://msc.abcroisiere.com/         NaN
# 2318  Soumettre                       https://msc.abcroisiere.com/         NaN
# 2353  Soumettre                     https://www.promovacances.com/         NaN
# 2758  Soumettre  https://www.fram.fr/sud-ouest/sejour-vacances-...         NaN
# 2792  Soumettre  https://www.fram.fr/provence-cote-d-azur/sejou...         NaN
# 2793  Soumettre  https://www.fram.fr/provence-cote-d-azur/sejou...         NaN
# 2798  Soumettre  https://www.fram.fr/maldives/sejour-vacances-v...         NaN
# 2808  Soumettre  https://www.promovacances.com/france/camping-c...         NaN
# 2830  Soumettre                                                NaN         NaN
# 2862  Soumettre                                                NaN         NaN
# 2863  Soumettre                                                NaN         NaN
# 2873  Soumettre                                                NaN         NaN
# 2874  Soumettre                                                NaN         NaN
# 2882  Soumettre                                                NaN         NaN
# 2883  Soumettre                                                NaN         NaN
# 2892  Soumettre  https://www.fram.fr/indonesie/sejour-vacances-...         NaN
# 2902  Soumettre                                                NaN         NaN
# 2933  Soumettre                                                NaN         NaN
# 2961  Soumettre  https://www.promovacances.com/france/camping-s...         NaN
# 3015  Soumettre  https://www.promovacances.com/vacances-sejour-...         NaN

# %%
def process_row(row):
    page_url = str(row['URL'])
    target = str(row['link_to_check'])

    if page_url == 'nan' or target == 'nan':
        return pd.Series({"anchor_text": None, "error": "URL vide"})

    anchor, error = get_anchor_text(page_url, target)
    return pd.Series({"anchor_text": anchor, "error": error})

# %%
df.loc[mask_search_anchor, ['anchor_text', 'error']] = (
    df.loc[mask_search_anchor].progress_apply(process_row, axis=1)
)
# Out:
# 100%|██████████| 47/47 [01:49<00:00,  2.33s/it]

# %%
df[mask_search_anchor]
# Out:
#                                                     URL             Tag  \
# 46    https://www.paris-normandie.fr/id657777/articl...   promovacances
# 68    https://www.courrier-picard.fr/id654609/articl...   promovacances
# 69    https://www.lemessager.fr/649340692/article/20...   promovacances
# 191           https://www.webwiki.fr/promocroisiere.com
# 207   https://www.lavoixdunord.fr/1625592/article/20...  promocroisiere
# 223              https://www.webwiki.fr/abcroisiere.com
# 239   https://www.lavoixdunord.fr/1614215/article/20...     abcroisiere
# 270   https://voyages-intrepides.com/croatie-comment...   promovacances
# 350   https://wholeterrain.org/divertissement/croisi...  promocroisiere
# 363   https://www.fox-voyage.fr/croisiere-autour-du-...  promocroisiere
# 391    https://luxe.net/cap-vert-levasion-sauvage-en...   promovacances
# 394   https://www.provenceweb.fr/f/actu/magazine/pro...            fram
# 651   https://www.voyagesphotosmanu.com/travel/les-d...            fram
# 1080  https://ghostsquadron.com/?s=Les+avantages+du+...   promovacances
# 1394  https://www.cafecitronparis.com/5-excellentes-...   promovacances
# 1555                     https://www.fureurdunoir.info/  promocroisiere
# 1927  https://www.hotelssabah.com/quel-est-linteret-...   promovacances
# 1941  https://www.guide-vols-low-cost.fr/que-faire-a...   promovacances
# 1966  https://www.voyages-voyage.com/pourquoi-choisi...   promovacances
# 1987  https://voyageblog.fr/quels-sont-les-avantages...   promovacances
# 2140  https://lepetitjournal.com/dublin/meilleurs-en...             NaN
# 2149  https://mesdoudouxetcompagnie.fr/2022/10/4-voy...             NaN
# 2150  https://www.guideastuces.com/A14438-5-bonnes-r...             NaN
# 2151  https://modesdevie.com/top-4-des-compagnies-de...             NaN
# 2185  https://www.voyages-voyage.com/pourquoi-opter-...            fram
# 2196  https://www.le-off.be/quels-sont-les-lieux-inc...     abcroisiere
# 2244  https://www.airvacances.fr/astuces-voyager-fai...   partirpascher
# 2310  https://www.airvacances.fr/partir-en-vacances-...     abcroisiere
# 2318  https://www.i-travelled.com/voyage-en-croisier...     abcroisiere
# 2353  https://www.fureurdunoir.info/partir-en-voyage...   promovacances
# 2758  https://www.convergence08.org/voyages/top-5-de...            fram
# 2792  https://www.evalys-bus.fr/camping-cote-dazur-q...            fram
# 2793  https://www.planete-crocodiles.net/cote-dazur-...            fram
# 2798  https://www.savennieres.com/les-activites-vaca...            fram
# 2808  https://www.mamachanblog.net/lifestyle/faire-d...   promovacances
# 2830  https://www.quartdetours.fr/criteres-de-choix-...             NaN
# 2862  https://www.chanoines-lagrasse.com/les-croisie...             NaN
# 2863  https://www.campingdelacroixdarles.com/quelles...             NaN
# 2873  https://www.chambreshotesjolivet.fr/croisiere-...             NaN
# 2874  https://www.refuge-jeandel.com/cabine-de-crois...             NaN
# 2882  https://www.lalignedhorizon.org/criteres-de-ch...             NaN
# 2883  https://www.tourisme-jouarre.com/comment-payer...             NaN
# 2892  https://www.voyages-thematiques.com/voyage-a-b...            fram
# 2902  https://www.sensationskite.com/un-navire-de-cr...             NaN
# 2933  https://www.camping-car-occasion.net/blog/cabi...             NaN
# 2961  https://www.mamanpascommelesautresoupresque.fr...   promovacances
# 3015  https://maxillo-lehavre.fr/pourquoi-opter-pour...   promovacances
#
#      Plateforme                                      link_to_check  \
# 46    Soumettre                     https://www.promovacances.com/
# 68    Soumettre  https://www.promovacances.com/vacances-sejour-...
# 69    Soumettre  https://www.promovacances.com/vacances-sejour-...
# 191   Soumettre                                            http://
# 207   Soumettre  https://www.promocroisiere.com/fr/croisieres/c...
# 223   Soumettre                                            http://
# 239   Soumettre  https://www.abcroisiere.com/fr/croisieres/croi...
# 270   Soumettre  https://www.promovacances.com/vacances-sejour-...
# 350   Soumettre  https://www.promocroisiere.com/fr/bateau-norwe...
# 363   Soumettre  https://www.promocroisiere.com/fr/croisieres/c...
# 391   Soumettre  https://www.promovacances.com/vacances-sejour-...
# 394   Soumettre                               https://www.fram.fr/
# 651   Soumettre                               https://www.fram.fr/
# 1080  Soumettre                     https://www.promovacances.com/
# 1394  Soumettre  https://www.promovacances.com/france/camping-c...
# 1555  Soumettre                    https://www.promocroisiere.com/
# 1927  Soumettre  https://www.promovacances.com/vacances-sejour-...
# 1941  Soumettre  https://www.promovacances.com/vacances-sejour-...
# 1966  Soumettre  https://www.promovacances.com/france/camping-o...
# 1987  Soumettre  https://www.promovacances.com/france/camping-c...
# 2140  Soumettre                                                NaN
# 2149  Soumettre                                                NaN
# 2150  Soumettre                                                NaN
# 2151  Soumettre                                                NaN
# 2185  Soumettre  https://www.fram.fr/espagne/sejour-vacances-vo...
# 2196  Soumettre                       https://www.abcroisiere.com/
# 2244  Soumettre                     https://www.partirpascher.com/
# 2310  Soumettre                       https://msc.abcroisiere.com/
# 2318  Soumettre                       https://msc.abcroisiere.com/
# 2353  Soumettre                     https://www.promovacances.com/
# 2758  Soumettre  https://www.fram.fr/sud-ouest/sejour-vacances-...
# 2792  Soumettre  https://www.fram.fr/provence-cote-d-azur/sejou...
# 2793  Soumettre  https://www.fram.fr/provence-cote-d-azur/sejou...
# 2798  Soumettre  https://www.fram.fr/maldives/sejour-vacances-v...
# 2808  Soumettre  https://www.promovacances.com/france/camping-c...
# 2830  Soumettre                                                NaN
# 2862  Soumettre                                                NaN
# 2863  Soumettre                                                NaN
# 2873  Soumettre                                                NaN
# 2874  Soumettre                                                NaN
# 2882  Soumettre                                                NaN
# 2883  Soumettre                                                NaN
# 2892  Soumettre  https://www.fram.fr/indonesie/sejour-vacances-...
# 2902  Soumettre                                                NaN
# 2933  Soumettre                                                NaN
# 2961  Soumettre  https://www.promovacances.com/france/camping-s...
# 3015  Soumettre  https://www.promovacances.com/vacances-sejour-...
#
#                                    anchor_text  \
# 46                                        None
# 68                                        None
# 69                                        None
# 191
# 207                                       None
# 223
# 239                                       None
# 270                          sur Promovacances
# 350
# 363              une croisière autour du monde
# 391                        séjour au Cap-Vert,
# 394                                       None
# 651                                       None
# 1080                                      None
# 1394                                      None
# 1555                                      None
# 1927            effectuer un voyage en espagne
# 1941                                      None
# 1966                                      None
# 1987  opter pour un Camping sur la Côte d’Azur
# 2140                                      None
# 2149                                      None
# 2150                                      None
# 2151                                      None
# 2185                                      None
# 2196                  recourir à une Croisière
# 2244                   pour un voyage pas cher
# 2310                             MSC Croisière
# 2318            toute la flotte MSC Croisières
# 2353             vous désirez partir en voyage
# 2758      avec des locations dans le Sud Ouest
# 2792     locations vacances sur la Côte d’Azur
# 2793   location de vacances sur la Côte d’Azur
# 2798                                    Button
# 2808                                      None
# 2830                                      None
# 2862                                      None
# 2863                                      None
# 2873                                      None
# 2874                                      None
# 2882                                      None
# 2883                                      None
# 2892                            voyager à Bali
# 2902                                      None
# 2933                                      None
# 2961                                      None
# 3015                                      None
#
#                                                   error
# 46    Page inaccessible: 403 Client Error: Forbidden...
# 68    Page inaccessible: 403 Client Error: Forbidden...
# 69    Page inaccessible: 403 Client Error: Forbidden...
# 191                                                None
# 207   Page inaccessible: 403 Client Error: Forbidden...
# 223                                                None
# 239   Page inaccessible: 403 Client Error: Forbidden...
# 270                                                None
# 350                                                None
# 363                                                None
# 391                                                None
# 394   Page inaccessible: 404 Client Error: Not Found...
# 651   Page inaccessible: HTTPSConnectionPool(host='w...
# 1080  Page inaccessible: 503 Server Error: Service T...
# 1394  Page inaccessible: 410 Client Error: Gone for ...
# 1555                      Lien introuvable dans la page
# 1927                                               None
# 1941  Page inaccessible: HTTPSConnectionPool(host='w...
# 1966  Page inaccessible: HTTPSConnectionPool(host='w...
# 1987                                               None
# 2140                                           URL vide
# 2149                                           URL vide
# 2150                                           URL vide
# 2151                                           URL vide
# 2185  Page inaccessible: HTTPSConnectionPool(host='w...
# 2196                                               None
# 2244                                               None
# 2310                                               None
# 2318                                               None
# 2353                                               None
# 2758                                               None
# 2792                                               None
# 2793                                               None
# 2798                                               None
# 2808                      Lien introuvable dans la page
# 2830                                           URL vide
# 2862                                           URL vide
# 2863                                           URL vide
# 2873                                           URL vide
# 2874                                           URL vide
# 2882                                           URL vide
# 2883                                           URL vide
# 2892                                               None
# 2902                                           URL vide
# 2933                                           URL vide
# 2961                      Lien introuvable dans la page
# 3015  Page inaccessible: HTTPSConnectionPool(host='m...

# %%
df['error'].unique()
# Out:
# array([nan,
#        'Page inaccessible: 403 Client Error: Forbidden for url: https://www.paris-normandie.fr/id657777/article/2025-09-10/voyage-ou-partir-pour-pas-cher-en-automne',
#        'Page inaccessible: 403 Client Error: Forbidden for url: https://www.courrier-picard.fr/id654609/article/2025-08-27/voyage-aux-seychelles-comment-bien-choisir-son-hebergement',
#        'Page inaccessible: 403 Client Error: Forbidden for url: https://www.lemessager.fr/649340692/article/2025-08-27/top-5-des-plus-belles-plages-de-l-ile-maurice',
#        None,
#        'Page inaccessible: 403 Client Error: Forbidden for url: https://www.lavoixdunord.fr/1625592/article/2025-09-17/msc-yacht-club-l-experience-vip-qui-vaut-le-coup',
#        'Page inaccessible: 403 Client Error: Forbidden for url: https://www.lavoixdunord.fr/1614215/article/2025-08-11/msc-croisieres-pourquoi-cette-compagnie-seduit-les-familles-francaises',
#        'Page inaccessible: 404 Client Error: Not Found for url: https://www.provenceweb.fr/f/actu/magazine/provencaux-vacances.htm%20',
#        "Page inaccessible: HTTPSConnectionPool(host='www.voyagesphotosmanu.com', port=443): Max retries exceeded with url: /travel/les-destinations-de-croisiere-depuis-la-france-les-plus-en-vue-en-2024/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DA79BED450>, 'Connection to www.voyagesphotosmanu.com timed out. (connect timeout=10)'))",
#        'Page inaccessible: 503 Server Error: Service Temporarily Unavailable for url: https://ghostsquadron.com/?s=Les+avantages+du+voyage+%22all+inclusive%22+%21',
#        'Page inaccessible: 410 Client Error: Gone for url: https://www.cafecitronparis.com/5-excellentes-raisons-de-faire-du-camping-en-corse',
#        'Lien introuvable dans la page',
#        "Page inaccessible: HTTPSConnectionPool(host='www.guide-vols-low-cost.fr', port=443): Max retries exceeded with url: /que-faire-au-cours-de-son-voyage-en-italie/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DA79BEEFD0>, 'Connection to www.guide-vols-low-cost.fr timed out. (connect timeout=10)'))",
#        "Page inaccessible: HTTPSConnectionPool(host='www.voyages-voyage.com', port=443): Max retries exceeded with url: /pourquoi-choisir-de-faire-un-camping-en-occitanie-pour-vos-vacances/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DA79BEF390>, 'Connection to www.voyages-voyage.com timed out. (connect timeout=10)'))",
#        'URL vide',
#        "Page inaccessible: HTTPSConnectionPool(host='www.voyages-voyage.com', port=443): Max retries exceeded with url: /pourquoi-opter-pour-un-sejour-en-espagne/ (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DA79BEF250>, 'Connection to www.voyages-voyage.com timed out. (connect timeout=10)'))",
#        "Page inaccessible: HTTPSConnectionPool(host='maxillo-lehavre.fr', port=443): Max retries exceeded with url: /pourquoi-opter-pour-un-sejour-a-punta-cana (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001DA79BEC2D0>, 'Connection to maxillo-lehavre.fr timed out. (connect timeout=10)'))"],
#       dtype=object)

# %%
df.to_excel("Soumettre_vdef.xlsx", index=False, engine="openpyxl")
